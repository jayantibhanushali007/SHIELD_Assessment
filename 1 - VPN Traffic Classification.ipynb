# %% [markdown]
# ### <center>Jayantilal Bhanushali </center>
# - Email: jay4datascience@gmail.com
# - Phone: +91 90164 70387
# - LinkedIn: https://www.linkedin.com/in/jayantilalb

# %% [markdown]
# ### Section A:
# #### How would you accurately predict if a certain app is a VPN app?

# %% [markdown]
# __Index:__
#
# 0. **[Initial Understanding of the Problem Statement](#understanding)**
# 1. **[Importing & Preparing Data](#import_data)**
# 2. **[Exploratory Data Analysis](#eda)**
# 3. **[Model Development on Full Data](#model_full)**
# 4. **[Model Development on Reduced Data](#model_reduced)**
# 5. **[Final Model with Hyper Parameter Optimization](#model_final)**
# 6. **[Conclusion](#conclusion)**
# 7. **[Way Forward](#way_forward)**

# %% [markdown]
# <a id='understanding'></a>
# __My Understanding of the Problem Statement:__
# - For SHIELD, One key problem is to address `Early Fraud Detection`. A common sign of a fraudulent device is the use of a VPN to hide its identity and avoid being traced.
# - Hence the problem of 'accurately predicting if a certain app is a VPN app' is an important feature to determine a potential threat (fraud device).
#
#
# __Use of Public Dataset:__
# - There were multiple labelled dataset available for VPN/ Non-VPN classification such as ISCX VPN-nonVPN Dataset (2016), MIT Lincoln VPN-nonVPN Network Dataset.
# - Based on the documentation available and the limited time for this assessment, I decided to go ahead with `ISCX VPN-nonVPN Dataset (2016)` since I could find good documentation about the dataset, some research papers using this dataset for similar objective and also since the official datasets were available in .ARFF format which can be read directly as Python DataFrame using Pandas.
# - Dataset link: http://205.174.165.80/CICDataset/ISCX-VPN-NonVPN-2016/Dataset/CSVs/
#
# __About the Dataset:__
# - The ISCX-VPN2016 dataset was used to develop a model in this study. The University of New Brunswick (UNB) made this dataset available for public use. It was collected by capturing experimental network traffic on a real-time basis in a customized lab. This data set takes into account seven different types of traffic: web browsing, email, chat, streaming, file transfer, VoIP, and P2P. The traffic was captured with Wireshark and TcpDump.
# - The final processed features dataset was then fed into two analysis scenarios: Scenario A was used to detect if the traffic is VPN or not and then tried to build classifiers to distinguish the type of encrypted traffic over VPN network connectivity. Scenario B used the labeled dataset, i.e., VPN and non-VPN instances, to form the second labeled dataset, in which the applications used to conduct the network-generated traffic were used as another variation of the instances’ labeling.
# - This dataset gained extra value related to the type of the features, which were either packet-based or time-based. Packet-based are those features that rely more on the protocol of the networking concept conducted, such as IPs, ports, and the flow of bytes amount. By contrast, the time-based features are considered as another dimension for the analysis that does not rely only on the statistic elements of the data, but rather on the variability of the time-based features. Timeouts for the time-based features were captured according to the discrete values that were measured in seconds, including 15, 30, 60, and 120 s.
# - We will be using `30s time interval dataset` since it offers a balanced compromise between the fine-grained temporal details captured in shorter intervals (e.g., 15s) and the broader aggregated insights offered by longer intervals (e.g., 120s)
#
#
# __Feature Description:__
#
# 1. **duration**: Duration of the flow.
# 2. **total_fiat**: Total forward inter-arrival time.
# 3. **total_biat**: Total backward inter-arrival time.
# 4. **min_fiat**: Minimum forward inter-arrival time.
# 5. **min_biat**: Minimum backward inter-arrival time.
# 6. **max_fiat**: Maximum forward inter-arrival time.
# 7. **max_biat**: Maximum backward inter-arrival time.
# 8. **mean_fiat**: Mean forward inter-arrival time.
# 9. **mean_biat**: Mean backward inter-arrival time.
# 10. **flowPktsPerSecond**: Number of flow packets per second.
# 11. **flowBytesPerSecond**: Number of flow bytes per second.
# 12. **min_flowiat**: Minimum flow inter-arrival time.
# 13. **max_flowiat**: Maximum flow inter-arrival time.
# 14. **mean_flowiat**: Mean flow inter-arrival time.
# 15. **std_flowiat**: Standard deviation of flow inter-arrival time.
# 16. **min_active**: Minimum active duration.
# 17. **mean_active**: Mean active duration.
# 18. **max_active**: Maximum active duration.
# 19. **std_active**: Standard deviation of active duration.
# 20. **min_idle**: Minimum idle duration.
# 21. **mean_idle**: Mean idle duration.
# 22. **max_idle**: Maximum idle duration.
# 23. **std_idle**: Standard deviation of idle duration.
# 24. **class1**: Label indicating whether the traffic is VPN or non-VPN.

# %% [markdown]
# <a id='import_data'> </a>
# ## 1: Importing & Preparing Data

# %%
# importing libraries:
import pandas as pd
from scipy.io import arff

#Data Visualization
import seaborn as sns
import matplotlib.pyplot as plt

# Data Preprocessing
from sklearn.preprocessing import StandardScaler, LabelEncoder

# ML Models
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

from sklearn.model_selection import GridSearchCV

# %%
# Reading the arff file 
arff_file = arff.loadarff(r'C:\Users\Jayanti\Downloads\SHIELD - Assessment\Dataset\Scenario A1-ARFF\TimeBasedFeatures-Dataset-30s-VPN.arff')

# Converting it into Pandas DF
raw_df = pd.DataFrame(arff_file[0])

print("Shape of Data", raw_df.shape)
print("#"*50)

# Check for missing values
print("Missing values count:\n", raw_df.isnull().sum())
print("#"*50)

print("Basic Info of Data\n",raw_df.info())
print("#"*50)

print("Distribution of Target Label\n", raw_df['class1'].value_counts())
# Out:
# Shape of Data (14651, 24)
# ##################################################
# Missing values count:
#  duration              0
# total_fiat            0
# total_biat            0
# min_fiat              0
# min_biat              0
# max_fiat              0
# max_biat              0
# mean_fiat             0
# mean_biat             0
# flowPktsPerSecond     0
# flowBytesPerSecond    0
# min_flowiat           0
# max_flowiat           0
# mean_flowiat          0
# std_flowiat           0
# min_active            0
# mean_active           0
# max_active            0
# std_active            0
# min_idle              0
# mean_idle             0
# max_idle              0
# std_idle              0
# class1                0
# dtype: int64
# ##################################################
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14651 entries, 0 to 14650
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ...

# %%
# View top 5 rows
raw_df.head()
# Out:
#      duration  total_fiat  total_biat    min_fiat    min_biat       max_fiat  \
# 0  22930417.0        18.0         4.0  10995965.0  10960941.0  314115.301370
# 1  25199304.0        16.0         4.0  11037969.0  10851858.0  359269.900000
# 2  29772995.0        17.0         7.0   4093396.0   3956161.0  261815.256637
# 3  29609149.0        22.0         6.0   3954677.0   3943698.0  271180.963303
# 4   7863522.0        30.0         8.0   2067690.0   2068091.0  244213.125000
#
#         max_biat     mean_fiat     mean_biat  flowPktsPerSecond  ...  \
# 0  360993.158730  1.306745e+06  1.389355e+06           6.018207  ...
# 1  387414.676923  1.373362e+06  1.392885e+06           5.436658  ...
# 2  310135.364583  6.445422e+05  6.512717e+05           7.086959  ...
# 3  287136.446602  6.685474e+05  6.590460e+05           7.227496  ...
# 4  252051.483871  5.718062e+05  5.628123e+05           8.266016  ...
#
#      std_flowiat  min_active   mean_active  max_active    std_active  \
# ...

# %% [markdown]
#  Insights:
#  - All the input variable columns are numerical in nature
#  - The Target variable column is categorical which needs to be transformed into binary (1=VPN, 0=Non-VPN)

# %%
# view unique values in 'class1' column
raw_df['class1'].unique()
# Out:
# array([b'Non-VPN', b'VPN'], dtype=object)

# %%
# Convert the 'Class1' column to binary class
raw_df['class1_binary'] = raw_df['class1'].apply(lambda x: 0 if x == b'Non-VPN' else 1)

# view the distribution of target variable
raw_df['class1_binary'].value_counts()
# Out:
# 1    7734
# 0    6917
# Name: class1_binary, dtype: int64

# %% [markdown]
# <a id='eda'></a>
# ## 2: Exploratory Data Analysis

# %%
# Distribution of the target variable
sns.countplot(x='class1_binary', data=raw_df)
plt.title('Distribution of Target Variable')
plt.show()

# Boxplots for numerical features with respect to the target variable
numerical_features = raw_df.columns[:-2]  # Exclude 'class1' and 'class1_binary'
plt.figure(figsize=(20, 15))
for i, feature in enumerate(numerical_features):
    plt.subplot(6, 4, i+1)
    sns.boxplot(x='class1_binary', y=feature, data=raw_df)
    plt.title(f'Boxplot of {feature}')
plt.tight_layout()
plt.show()

# Pairplot to visualize pairwise relationships
sns.pairplot(raw_df, hue='class1_binary', vars=numerical_features[:5])  # Limiting to first 5 features for readability
plt.show()

# Correlation heatmap
corr_matrix = raw_df.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Set display option to avoid scientific notation
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Describe the full dataset
full_description = raw_df.describe()
print("Full Dataset Description:\n")
display(full_description)

# Describe the dataset where class1_binary is 1 (VPN)
vpn_description = raw_df[raw_df['class1_binary'] == 1].describe()
print("\nVPN Dataset Description:\n") 
display(vpn_description)

# Describe the dataset where class1_binary is 0 (Non-VPN)
non_vpn_description = raw_df[raw_df['class1_binary'] == 0].describe()
print("\nNon-VPN Dataset Description:\n") 
display(non_vpn_description)
# Out:
# Full Dataset Description:
#            duration   total_fiat   total_biat      min_fiat      min_biat  \
# count     14651.000    14651.000    14651.000     14651.000     14651.000
# mean   16296780.414  1150691.576  1116318.755   5764142.369   5091317.884
# std    19255515.817  4111790.265  4017207.558  13443200.681  12184996.491
# min           0.000       -1.000       -1.000        -1.000        -1.000
# 25%      274174.000        7.000        1.000     26884.000     24678.500
# 50%    16232620.000       57.000       21.000    420458.000    451705.000
# 75%    29778024.500     1105.000      467.500   8848114.000   8907444.500
# max   601404954.000 37680787.000 43002377.000 303595747.000 600109667.000
#
#            max_fiat     max_biat     mean_fiat    mean_biat  \
# count     14651.000    14651.000     14651.000    14651.000
# mean    1848038.640  1710895.405   1449869.403  1179028.674
# std     4959792.844  4295170.408   5477288.341  3541896.070
# ...

# %%
# create a copy of the raw dataframe
raw_df_scaled = raw_df.copy()

# Define the features to be scaled (excluding 'class1' and 'class1_binary')
features_to_scale = raw_df.columns[:-2]

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit and transform the features
raw_df_scaled[features_to_scale] = scaler.fit_transform(raw_df[features_to_scale])

# Display the first few rows of the scaled dataframe
raw_df_scaled.head()
# Out:
#    duration  total_fiat  total_biat  min_fiat  min_biat  max_fiat  max_biat  \
# 0     0.345      -0.280      -0.278     0.389     0.482    -0.309    -0.314
# 1     0.462      -0.280      -0.278     0.392     0.473    -0.300    -0.308
# 2     0.700      -0.280      -0.278    -0.124    -0.093    -0.320    -0.326
# 3     0.691      -0.280      -0.278    -0.135    -0.094    -0.318    -0.331
# 4    -0.438      -0.280      -0.278    -0.275    -0.248    -0.323    -0.340
#
#    mean_fiat  mean_biat  flowPktsPerSecond  ...  min_active  mean_active  \
# 0     -0.026      0.059             -0.134  ...      -0.228       -0.064
# 1     -0.014      0.060             -0.134  ...      -0.215       -0.116
# 2     -0.147     -0.149             -0.134  ...      -0.236       -0.205
# 3     -0.143     -0.147             -0.134  ...      -0.231       -0.191
# 4     -0.160     -0.174             -0.134  ...      -0.191       -0.216
#
#    max_active  std_active  min_idle  mean_idle  max_idle  std_idle  \
# ...

# %%
# Boxplots for numerical features with respect to the target variable
numerical_features = raw_df_scaled.columns[:-2]  # Exclude 'class1' and 'class1_binary'
plt.figure(figsize=(20, 15))
for i, feature in enumerate(numerical_features):
    plt.subplot(6, 4, i+1)
    sns.boxplot(x='class1_binary', y=feature, data=raw_df_scaled)
    plt.title(f'Boxplot of {feature}')
plt.tight_layout()
plt.show()

# %% [markdown]
# Insight:

# %% [markdown]
# - For each feature, Outliers (or volatility) are typically observed in either VPN or Non-VPN records, but there are very few features where outliers are observed in both the classes.

# %% [markdown]
# <a id='model_full'></a>
# ## 3: Model Development on Full Data:

# %%
# Define the features (X) and target (y)
X = raw_df_scaled.drop(columns=['class1', 'class1_binary'])
y = raw_df_scaled['class1_binary']

# Split the dataset into training and testing sets (70:30)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Display the shapes of the resulting datasets
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (10255, 23)
# X_test shape: (4396, 23)
# y_train shape: (10255,)
# y_test shape: (4396,)

# %%
# Initialize models
models = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'XGBoost': XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
    'SVM': SVC()
}

# Train and evaluate models
results = {}
for model_name, model in models.items():
    # Cross-validation
    cv_scores = cross_val_score(model, X_train, y_train, cv=5)
    print(f"{model_name} CV Accuracy: {cv_scores.mean():.4f} ± {cv_scores.std():.4f}")
    
    # Train the model
    model.fit(X_train, y_train)
    
    # Predict on test data
    y_pred = model.predict(X_test)
    
    # Classification report
    print(f"\n{model_name} Classification Report:\n")
    print(classification_report(y_test, y_pred))
    
    # Store results
    results[model_name] = {
        'accuracy': accuracy_score(y_test, y_pred),
        'precision': precision_score(y_test, y_pred),
        'recall': recall_score(y_test, y_pred)
    }
# Out:
# Logistic Regression CV Accuracy: 0.6249 ± 0.0073
#
# Logistic Regression Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.63      0.41      0.50      2088
#            1       0.59      0.78      0.68      2308
#
#     accuracy                           0.61      4396
#    macro avg       0.61      0.60      0.59      4396
# weighted avg       0.61      0.61      0.59      4396
#
# Decision Tree CV Accuracy: 0.8584 ± 0.0043
#
# Decision Tree Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85      2088
#            1       0.86      0.88      0.87      2308
#
#     accuracy                           0.86      4396
#    macro avg       0.86      0.86      0.86      4396
# weighted avg       0.86      0.86      0.86      4396
#
# Random Forest CV Accuracy: 0.8937 ± 0.0064
#
# Random Forest Classification Report:
#
# ...

# %%
# Prepare data for plotting
plot_data = []
for model_name, metrics_dict in results.items():
    for metric, value in metrics_dict.items():
        plot_data.append({'Model': model_name, 'Metric': metric, 'Value': value})

# Convert to DataFrame
plot_df = pd.DataFrame(plot_data)

# Create the bar plot
plt.figure(figsize=(12, 8))
sns.barplot(x='Metric', y='Value', hue='Model', data=plot_df)
plt.title('Model Performance Comparison')
plt.ylabel('Score')
plt.ylim(0, 1)
plt.show()

# %% [markdown]
# <a id='model_reduced'></a>
# ## 4: Model Development on Redued Data (after correlation)

# %%
# Set the correlation threshold
correlation_threshold = 0.9

# Create a correlation matrix
corr_matrix = raw_df_scaled.corr()

# Identify columns to drop
columns_to_drop = set()
for i in range(len(corr_matrix.columns)):
    for j in range(i):
        if abs(corr_matrix.iloc[i, j]) > correlation_threshold:
            colname = corr_matrix.columns[i]
            columns_to_drop.add(colname)

# Drop the identified columns
raw_df_reduced = raw_df_scaled.drop(columns=columns_to_drop)

# Display the columns to be dropped
print("Columns to be dropped due to high correlation:")
print(columns_to_drop)

# Display the reduced dataframe
raw_df_reduced.head()
# Out:
# Columns to be dropped due to high correlation:
# {'min_active', 'max_idle', 'min_idle', 'max_active', 'mean_active', 'mean_idle', 'max_biat', 'std_idle'}
#    duration  total_fiat  total_biat  min_fiat  min_biat  max_fiat  mean_fiat  \
# 0     0.345      -0.280      -0.278     0.389     0.482    -0.309     -0.026
# 1     0.462      -0.280      -0.278     0.392     0.473    -0.300     -0.014
# 2     0.700      -0.280      -0.278    -0.124    -0.093    -0.320     -0.147
# 3     0.691      -0.280      -0.278    -0.135    -0.094    -0.318     -0.143
# 4    -0.438      -0.280      -0.278    -0.275    -0.248    -0.323     -0.160
#
#    mean_biat  flowPktsPerSecond  flowBytesPerSecond  min_flowiat  max_flowiat  \
# 0      0.059             -0.134              -0.054       -0.086        0.249
# 1      0.060             -0.134              -0.054       -0.086        0.243
# 2     -0.149             -0.134              -0.054       -0.086       -0.166
# ...

# %%
# Define the features (X) and target (y)
X = raw_df_reduced.drop(columns=['class1', 'class1_binary'])
y = raw_df_reduced['class1_binary']

# Split the dataset into training and testing sets (70:30)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize models
models = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'XGBoost': XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
    'SVM': SVC()
}


# Train and evaluate models
results = {}
for model_name, model in models.items():
    # Cross-validation
    cv_scores = cross_val_score(model, X_train, y_train, cv=5)
    print(f"{model_name} CV Accuracy: {cv_scores.mean():.4f} ± {cv_scores.std():.4f}")
    
    # Train the model
    model.fit(X_train, y_train)
    
    # Predict on test data
    y_pred = model.predict(X_test)
    
    # Classification report
    print(f"\n{model_name} Classification Report:\n")
    print(classification_report(y_test, y_pred))
    
    # Store results
    results[model_name] = {
        'accuracy': accuracy_score(y_test, y_pred),
        'precision': precision_score(y_test, y_pred),
        'recall': recall_score(y_test, y_pred)
    }


# Prepare data for plotting
plot_data = []
for model_name, metrics_dict in results.items():
    for metric, value in metrics_dict.items():
        plot_data.append({'Model': model_name, 'Metric': metric, 'Value': value})

# Convert to DataFrame
plot_df = pd.DataFrame(plot_data)

# Create the bar plot
plt.figure(figsize=(12, 8))
sns.barplot(x='Metric', y='Value', hue='Model', data=plot_df)
plt.title('Model Performance Comparison')
plt.ylabel('Score')
plt.ylim(0, 1)
plt.show()
# Out:
# Logistic Regression CV Accuracy: 0.5994 ± 0.0106
#
# Logistic Regression Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.39      0.47      2088
#            1       0.58      0.76      0.66      2308
#
#     accuracy                           0.58      4396
#    macro avg       0.59      0.57      0.56      4396
# weighted avg       0.59      0.58      0.57      4396
#
# Decision Tree CV Accuracy: 0.8638 ± 0.0061
#
# Decision Tree Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.85      2088
#            1       0.85      0.88      0.87      2308
#
#     accuracy                           0.86      4396
#    macro avg       0.86      0.85      0.86      4396
# weighted avg       0.86      0.86      0.86      4396
#
# Random Forest CV Accuracy: 0.8967 ± 0.0053
#
# Random Forest Classification Report:
#
# ...

# %% [markdown]
# Insight:
# - RF and XGBoost algorithms have shown very similar overall performance on Full Data as well as Reduced Data.
# - We will go ahead with RF since it is less complex, faster than XGBoost and can provide with list of important features for explanability

# %% [markdown]
# <a id='model_final'></a>
# ## 5: Final model using Random Forest with Hyper parameter optimization

# %%
from sklearn.model_selection import GridSearchCV
import seaborn as sns

import matplotlib.pyplot as plt

# Define the features (X) and target (y)
X = raw_df_reduced.drop(columns=['class1', 'class1_binary'])
y = raw_df_reduced['class1_binary']

# Split the dataset into training and testing sets (70:30)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Define the parameter grid for hyperparameter optimization
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# Initialize the Random Forest model
rf = RandomForestClassifier(random_state=42)

# Initialize GridSearchCV with 5-fold cross-validation
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, n_jobs=1, verbose=1, scoring='recall') # Recall since we want to focus specially on deteccting all VPN apps

# Fit the model
grid_search.fit(X_train, y_train)

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("Best Parameters:", best_params)
print("Best Cross-Validation Score:", best_score)

# Train the final model with the best parameters
final_rf = RandomForestClassifier(**best_params, random_state=42)
final_rf.fit(X_train, y_train)

# Predict on the test data
y_pred = final_rf.predict(X_test)

# Classification report
print("\nFinal Random Forest Classification Report:\n")
print(classification_report(y_test, y_pred))

# Cross-validation scores for the final model
cv_scores = cross_val_score(final_rf, X_train, y_train, cv=5)

# Prepare data for plotting
plot_data = [{'Metric': 'Accuracy', 'Value': cv_scores.mean()}]

# Convert to DataFrame
plot_df = pd.DataFrame(plot_data)

# Create the bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Metric', y='Value', data=plot_df)
plt.title('Cross-Validation Scores for Final Random Forest Model')
plt.ylabel('Score')
plt.ylim(0, 1)
plt.show()
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.4s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.4s
# ...

# %%
# Get feature importances from the final Random Forest model
importances = final_rf.feature_importances_

# Create a DataFrame for better visualization
feature_importance_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': importances
})

# Sort the DataFrame by importance
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plot the feature importances
plt.figure(figsize=(12, 8))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df)
plt.title('Feature Importance from Final Random Forest Model')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# <a id='conclusion'></a>
# ## 6: Conclusion:

# %% [markdown]
# The top 5 important features of determining the VPN vs. Non-VPN traffic are:
#
#
# #### **1. total_biat (Total Backward Inter-Arrival Time)**
# This feature measures the **total time between packets traveling backward** in a communication flow.
#
# - **VPN Traffic:** Often shows more **uniform or delayed backward inter-arrival times** due to packet encapsulation and encryption overhead.
# - **Non-VPN Traffic:** Typically has **more natural variations** in backward timings since no encryption or additional layers alter packet behavior.
#
# **Insight:** *If backward packet timing is consistent and slightly delayed, it’s more likely VPN traffic.*
#
# ---
#
# #### **2. min_flowiat (Minimum Flow Inter-Arrival Time)**
# This captures the **shortest time gap between two packets in the flow**.
#
# - **VPN Traffic:** Encryption and encapsulation often cause **slight delays**, increasing the minimum inter-arrival time.
# - **Non-VPN Traffic:** Direct communication typically allows **faster inter-arrival times** with lower delays.
#
# **Insight:** *A slightly higher minimum inter-arrival time might hint at VPN encapsulation overhead.*
#
# ---
#
# #### **3. flowBytesPerSecond (Number of Flow Bytes per Second)**
# This feature measures the **rate of data transmission per second** in a flow.
#
# - **VPN Traffic:** Tends to have **more consistent or throttled data flow rates** because VPN protocols (like OpenVPN or WireGuard) standardize packet sizes and flow rates to reduce detectability.
# - **Non-VPN Traffic:** Displays **variable data flow rates** based on application-specific behaviors (e.g., streaming vs. text communication).
#
# **Insight:** *A steady and regulated byte-per-second rate often suggests VPN traffic.*
#
# ---
#
# #### **4. total_fiat (Total Forward Inter-Arrival Time)**
# This measures the **total time between packets traveling forward** in the communication flow.
#
# - **VPN Traffic:** Forward inter-arrival times might exhibit **more uniformity** due to VPN buffering mechanisms.
# - **Non-VPN Traffic:** More **variability** is expected as different applications and protocols send packets based on real-time demands.
#
# **Insight:** *If total forward inter-arrival time shows uniform patterns, it leans towards VPN traffic.*
#
# ---
#
# #### **5. max_flowiat (Maximum Flow Inter-Arrival Time)**
# This captures the **longest time gap between two packets in the flow**.
#
# - **VPN Traffic:** Long inter-packet delays might be **less frequent** due to buffering mechanisms in VPN tunnels.
# - **Non-VPN Traffic:** Natural variability might result in **occasional large gaps** between packets.
#
# **Insight:** *Consistent maximum flow inter-arrival times are a subtle indicator of VPN traffic.*

# %% [markdown]
# <a id='way_forward'></a>
# ## 7: Way Forward:
#
# - The learnings from the above dataset can be used to develop a new model or integrate it with an existing model.
# - There are certain other factors that can help us identify if the app is VPN or Non-VPN:
#     - App Metadata Analysis (Look for keywords like "VPN," "Proxy," "Tunnel," "Secure Network.")
#     - Permissions Analysis (VPN apps usually require permissions such as: FOREGROUND_SERVICE, BIND_VPN_SERVICE ACCESS_NETWORK_STATE)
#     - System APIs Used (Android: VpnService class, iOS: NETunnelProviderManager, NEVPNManager)
# - Depending upon the north start metric (speed or quality), we can deploy ML or heuristic approach to detect VPN traffic and prevent potential Fraud from those devices.
